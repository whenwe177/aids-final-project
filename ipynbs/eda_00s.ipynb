# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import scipy.stats as scp

# %%
twothousands_df = pd.read_csv("../2000.csv")
year_df = twothousands_df["year"]
bpm_df = twothousands_df["bpm"]
dnce_df = twothousands_df["dnce"]
dB_df = twothousands_df["dB"]
live_df = twothousands_df["live"]
val_df = twothousands_df["val"]
dur_df = twothousands_df["dur"]
acous_df = twothousands_df["acous"]
spch_df = twothousands_df["spch"]
popularity_df = twothousands_df["popularity"]

# %%
twothousands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          100 non-null    object
#  1   artist         100 non-null    object
#  2   genre          100 non-null    object
#  3   year           100 non-null    int64
#  4   bpm            100 non-null    int64
#  5   nrgy           100 non-null    int64
#  6   dnce           100 non-null    int64
#  7   dB             100 non-null    int64
#  8   live           100 non-null    int64
#  9   val            100 non-null    int64
#  10  dur            100 non-null    int64
#  11  acous          100 non-null    int64
#  12  spch           100 non-null    int64
#  13  popularity     100 non-null    int64
#  14  has_win_award  100 non-null    float64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 11.8+ KB

# %%
# Compute additional information
dfs = ["bpm", "dnce", "dB", "live", "val", "dur", "acous", "spch", "popularity"]
stats_dfs = []

for df in dfs:
    curr_df  = twothousands_df[df]
    Q1 = np.percentile(curr_df, 25, method='midpoint')
    Q3 = np.percentile(curr_df, 75, method='midpoint')
    IQR = Q3-Q1  # Interquartile range

    stats = [
        ['Mean', np.mean(curr_df)],
        ['Median', np.median(curr_df)],
        ['Mode', scp.mode(curr_df)[0][0]],
        ['Standard Deviation', np.std(curr_df)],
        ['Variance', np.var(curr_df)],
        ['Minimum', np.min(curr_df)],
        ['Maximum', np.max(curr_df)],
        ['Q1', Q1],
        ['Q3', Q3],
        ['IQR', IQR],
        ['RLB', Q1-1.5*IQR],  # Reasonable Lower Bound
        ['RUB', Q3+1.5*IQR],  # Reasonable Upper Bound
    ]

    print(f'{df.upper()} Description')
    display(pd.DataFrame(stats, columns=['Measure', 'Value']))
# Out:
# BPM Description
#                Measure       Value
# 0                 Mean  118.800000
# 1               Median  120.000000
# 2                 Mode  130.000000
# 3   Standard Deviation   23.236179
# 4             Variance  539.920000
# 5              Minimum   77.000000
# 6              Maximum  180.000000
# 7                   Q1   99.500000
# 8                   Q3  130.000000
# 9                  IQR   30.500000
# 10                 RLB   53.750000
# 11                 RUB  175.750000
# DNCE Description
#                Measure       Value
# 0                 Mean   68.530000
# 1               Median   67.000000
# 2                 Mode   62.000000
# 3   Standard Deviation   14.213694
# 4             Variance  202.029100
# 5              Minimum   21.000000
# 6              Maximum   96.000000
# 7                   Q1   60.500000
# 8                   Q3   79.000000
# 9                  IQR   18.500000
# 10                 RLB   32.750000
# 11                 RUB  106.750000
# ...

# %%
## Boxplot visualization
for df in dfs:
    plt.title(f'Boxplot for {df.upper()}')
    sns.boxplot(x=df, data=twothousands_df)
    plt.show()

    curr_df  = twothousands_df[df]
    Q1 = np.percentile(curr_df, 25, method='midpoint')
    Q3 = np.percentile(curr_df, 75, method='midpoint')
    IQR = Q3-Q1  # Interquartile range

    RLB = Q1 - 1.5*IQR
    RUB = Q3 + 1.5*IQR
    print("Outlier exists?", np.max(curr_df) > RUB, "\n----------------------------------------------")
# Out:
# Outlier exists? True
# ----------------------------------------------
# Outlier exists? False
# ----------------------------------------------
# Outlier exists? False
# ----------------------------------------------
# Outlier exists? True
# ----------------------------------------------
# Outlier exists? False
# ----------------------------------------------
# Outlier exists? False
# ----------------------------------------------
# Outlier exists? True
# ----------------------------------------------
# Outlier exists? True
# ----------------------------------------------
# Outlier exists? False
# ----------------------------------------------

# %%
kde_dfs = ["spch", "live", "bpm", "acous"]

for df in kde_dfs:
    plt.figure(figsize=(7,5))
    plt.gca().set_ylim([None, 0.2])
    sns.kdeplot(data = twothousands_df[df], shade=True)
    plt.vlines(x=np.mean(twothousands_df[df]), ymin=0, ymax=0.175, color='blue', linestyle='--')
    plt.vlines(x=np.median(twothousands_df[df]), ymin=0, ymax=0.175, color='brown', linestyle='--')
    plt.vlines(x=scp.mode(twothousands_df[df])[0][0], ymin=0, ymax=0.175, color='red', linestyle='--')
    plt.legend([f'Average{df.capitalize()}', 'Mean', 'Median', 'Mode'], fontsize=12)
    plt.title(f"{df} KDE plot")
    plt.show()

# %%
## Pie chart for genres
genre_df = twothousands_df["genre"]
genre_count = genre_df.value_counts()

genre_count.plot(
    kind="pie",
    figsize=(10,10),
    title="Pie Chart of Genres",
    ylabel="",
    autopct='%1.1f%%'
    )
# Out:
# <AxesSubplot:title={'center':'Pie Chart of Genres'}>

# %%
plt.figure(figsize=(10,10))

sns.heatmap(
    twothousands_df.select_dtypes(np.number).corr(),
    annot=True,
    cbar=False,
    fmt="0.2f",
    cmap="YlGnBu",
    xticklabels=twothousands_df.select_dtypes(np.number).columns,
    yticklabels=twothousands_df.select_dtypes(np.number).columns
    
    )
plt.title("Correlation matrix")
# Out:
# Text(0.5, 1.0, 'Correlation matrix')
