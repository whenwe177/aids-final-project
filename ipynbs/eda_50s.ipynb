# %%
import pandas as pd
import numpy as np
import sklearn as sk
import seaborn as sns
import plotly.express as px
import scipy.stats as scp
import matplotlib.pyplot as plt

# %%
song50s = pd.read_csv("../1950.csv")

# %%
# Descriptive statistics
# Statistics for numeric attributes (mean, median, mode, RUB, RLB, )
numericalValues = ["bpm", "nrgy", "dnce", "dB", "live", "val", "dur", "acous", "spch", "popularity"]

for key in numericalValues:
    chosenTable = song50s[key]
    
    q1 = np.quantile(chosenTable, 0.25, interpolation="midpoint")
    q3 = np.quantile(chosenTable, 0.75, interpolation="midpoint")
    iqr = q3 - q1
    rlb = q1 - 1.5 * iqr
    rub = q3 + 1.5 * iqr
    
    print(f"Description for {key}:")
    descriptionTable = [
        ["Minimum", np.min(chosenTable)],
        ["Maximum", np.max(chosenTable)],
        ["Mean", np.mean(chosenTable)],
        ["Median", np.median(chosenTable)],
        ["Mode", scp.mode(chosenTable)[0][0]],
        ["Variance", np.var(chosenTable)],
        ["Standard Deviation", np.std(chosenTable)],
        ["Q1", q1],
        ["Q3", q3],
        ["IQR", iqr],
        ["RLB", rlb],
        ["RUB", rub]
    ]
    
    display(pd.DataFrame(descriptionTable, columns=["Measure", "Value"]))
# Out:
# Description for bpm:
#                Measure       Value
# 0              Minimum   72.000000
# 1              Maximum  195.000000
# 2                 Mean  111.150685
# 3               Median  108.000000
# 4                 Mode   79.000000
# 5             Variance  775.826609
# 6   Standard Deviation   27.853664
# 7                   Q1   87.000000
# 8                   Q3  128.000000
# 9                  IQR   41.000000
# 10                 RLB   25.500000
# 11                 RUB  189.500000
# Description for nrgy:
#                Measure       Value
# 0              Minimum    6.000000
# 1              Maximum   97.000000
# 2                 Mean   34.890411
# 3               Median   33.000000
# 4                 Mode   14.000000
# 5             Variance  299.001689
# 6   Standard Deviation   17.291665
# 7                   Q1   21.000000
# 8                   Q3   44.000000
# 9                  IQR   23.000000
# 10                 RLB  -13.500000
# 11                 RUB   78.500000
# Description for dnce:
#                Measure       Value
# 0              Minimum   18.000000
# 1              Maximum   88.000000
# 2                 Mean   51.027397
# 3               Median   52.000000
# 4                 Mode   55.000000
# 5             Variance  207.451304
# 6   Standard Deviation   14.403170
# 7                   Q1   41.000000
# 8                   Q3   59.000000
# 9                  IQR   18.000000
# 10                 RLB   14.000000
# 11                 RUB   86.000000
# Description for dB:
#                Measure      Value
# 0              Minimum -18.000000
# 1              Maximum  -2.000000
# 2                 Mean -11.616438
# 3               Median -10.000000
# 4                 Mode -10.000000
# 5             Variance  11.578908
# 6   Standard Deviation   3.402779
# 7                   Q1 -15.000000
# 8                   Q3  -9.000000
# 9                  IQR   6.000000
# 10                 RLB -24.000000
# 11                 RUB   0.000000
# Description for live:
#                Measure       Value
# 0              Minimum    2.000000
# 1              Maximum   72.000000
# 2                 Mean   18.150685
# 3               Median   13.000000
# 4                 Mode   10.000000
# 5             Variance  142.155376
# 6   Standard Deviation   11.922893
# 7                   Q1   10.000000
# 8                   Q3   24.000000
# 9                  IQR   14.000000
# 10                 RLB  -11.000000
# 11                 RUB   45.000000
# Description for val:
#                Measure       Value
# 0              Minimum   10.000000
# 1              Maximum   99.000000
# 2                 Mean   57.589041
# 3               Median   57.000000
# 4                 Mode   47.000000
# 5             Variance  620.735222
# 6   Standard Deviation   24.914558
# 7                   Q1   36.000000
# 8                   Q3   79.000000
# 9                  IQR   43.000000
# 10                 RLB  -28.500000
# 11                 RUB  143.500000
# Description for dur:
#                Measure       Value
# 0              Minimum   98.000000
# 1              Maximum  214.000000
# 2                 Mean  149.534247
# 3               Median  148.000000
# 4                 Mode  135.000000
# 5             Variance  500.111841
# 6   Standard Deviation   22.363180
# 7                   Q1  135.000000
# 8                   Q3  163.000000
# 9                  IQR   28.000000
# 10                 RLB   93.000000
# 11                 RUB  205.000000
# Description for acous:
#                Measure       Value
# 0              Minimum    4.000000
# 1              Maximum  100.000000
# 2                 Mean   73.013699
# 3               Median   79.000000
# 4                 Mode   82.000000
# 5             Variance  399.684744
# 6   Standard Deviation   19.992117
# 7                   Q1   63.000000
# 8                   Q3   87.000000
# 9                  IQR   24.000000
# 10                 RLB   27.000000
# 11                 RUB  123.000000
# Description for spch:
#                Measure      Value
# 0              Minimum   3.000000
# 1              Maximum  11.000000
# 2                 Mean   4.191781
# 3               Median   3.000000
# 4                 Mode   3.000000
# 5             Variance   3.223494
# 6   Standard Deviation   1.795409
# 7                   Q1   3.000000
# 8                   Q3   4.000000
# 9                  IQR   1.000000
# 10                 RLB   1.500000
# 11                 RUB   5.500000
# Description for popularity:
#                Measure       Value
# 0              Minimum   26.000000
# 1              Maximum   72.000000
# 2                 Mean   40.863014
# 3               Median   39.000000
# 4                 Mode   39.000000
# 5             Variance  105.762057
# 6   Standard Deviation   10.284068
# 7                   Q1   33.000000
# 8                   Q3   48.000000
# 9                  IQR   15.000000
# 10                 RLB   10.500000
# 11                 RUB   70.500000

# %%
# Statistics for categorical attributes
categoricalValues = ["artist", "genre", "has_win_award"]
for key in categoricalValues:
    print(f"Description for {key}")
    descriptionTable = [
        ["Unique", len(pd.unique(song50s[key]))],
        ["Mode", song50s[key].mode()[0]]
    ]
    
    display(pd.DataFrame(descriptionTable, columns=["Measure", "Value"]))

song50s.describe(include="object")
# Out:
# Description for artist
#   Measure          Value
# 0  Unique             59
# 1    Mode  Craig Douglas
# Description for genre
#   Measure            Value
# 0  Unique               12
# 1    Mode  adult standards
# Description for has_win_award
#   Measure  Value
# 0  Unique    1.0
# 1    Mode    0.0
#                                               title       artist  \
# count                                            73           73
# unique                                           73           59
# top     Take Good Care Of My Baby - 1990 Remastered  Dean Martin
# freq                                              1            3
#
#                   genre
# count                61
# unique               11
# top     adult standards
# freq                 33

# %%
# Dataframe information
song50s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          73 non-null     object
#  1   artist         73 non-null     object
#  2   genre          61 non-null     object
#  3   year           73 non-null     int64
#  4   bpm            73 non-null     int64
#  5   nrgy           73 non-null     int64
#  6   dnce           73 non-null     int64
#  7   dB             73 non-null     int64
#  8   live           73 non-null     int64
#  9   val            73 non-null     int64
#  10  dur            73 non-null     int64
#  11  acous          73 non-null     int64
#  12  spch           73 non-null     int64
#  13  popularity     73 non-null     int64
#  14  has_win_award  73 non-null     float64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 7.8+ KB

# %%
# KDE plots

for key in numericalValues:
    chosenTable = song50s[key]
    
    plt.figure(figsize=(7,5))
    sns.kdeplot(data = chosenTable, shade = True)
    plt.vlines(x=np.mean(chosenTable),ymin=0, ymax=0.35, color="blue", linestyle="--")
    plt.vlines(x=np.median(chosenTable),ymin=0, ymax=0.35, color="brown", linestyle="--")
    plt.vlines(x=scp.mode(chosenTable)[0][0],ymin=0, ymax=0.35, color="red", linestyle="--")
    
    plt.legend([key, "Mean", "Median", "Mode"])

# %%
# Box plots
for key in numericalValues:
    print(f"Box plot for {key} per genre")
    figure = px.box(song50s.dropna(), y=key, color="genre")
    figure.show()
    
    print(f"Overall box plot for {key}")
    figure = px.box(song50s[key], y=key)
    figure.show()
# Out:
# Box plot for bpm per genre
# <div>                            <div id="94b837a7-60cb-4e3a-af77-815ebc6bbce2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94b837a7-60cb-4e3a-af77-815ebc6bbce2")) {                    Plotly.newPlot(                        "94b837a7-60cb-4e3a-af77-815ebc6bbce2",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>bpm=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[116,177,81,82,79,182,102,123,97,123,78,77,72,91,79,143,148,80,73,127,107,95,135,128,79,127,106,108,103,86,81,108,155],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>bpm=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[114,148,110,195,147,81,147,84,114],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>bpm=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[137,130,92,167],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>bpm=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[105,123,126,137,106,125,109],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>bpm=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[93],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>bpm=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[75],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>bpm=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[84],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>bpm=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[90],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>bpm=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[87,131],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>bpm=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[102],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<b ...
# Overall box plot for bpm
# <div>                            <div id="a9fe40cf-1b94-4d3a-bce1-f18acc0f1262" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9fe40cf-1b94-4d3a-bce1-f18acc0f1262")) {                    Plotly.newPlot(                        "a9fe40cf-1b94-4d3a-bce1-f18acc0f1262",                        [{"alignmentgroup":"True","hovertemplate":"bpm=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[116,177,81,82,79,182,102,123,97,123,78,114,77,137,130,105,72,91,148,79,143,148,80,110,73,127,107,95,135,195,93,113,138,128,79,75,127,106,123,108,92,103,114,147,86,84,81,81,147,108,100,126,167,137,90,106,84,97,109,87,102,75,131,125,114,109,97,83,155,142,93,137,109],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}] ...
# Box plot for nrgy per genre
# <div>                            <div id="0a248d91-d894-4103-b9fc-e787154f4e26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a248d91-d894-4103-b9fc-e787154f4e26")) {                    Plotly.newPlot(                        "0a248d91-d894-4103-b9fc-e787154f4e26",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>nrgy=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[34,34,49,43,38,14,41,36,9,43,10,6,43,17,12,43,46,22,28,64,31,97,71,29,14,17,16,14,44,16,12,39,44],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>nrgy=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[31,65,32,27,32,20,37,39,55],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>nrgy=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[47,27,11,50],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>nrgy=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[28,45,31,21,55,33,65],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>nrgy=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[45],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>nrgy=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[26],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>nrgy=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[33],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>nrgy=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[27],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>nrgy=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[46,34],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>nrgy=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[19],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<br>nrgy=%{y}<extra></extra>"," ...
# Overall box plot for nrgy
# <div>                            <div id="24800fec-164a-4dac-9f0c-ea2712b808ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24800fec-164a-4dac-9f0c-ea2712b808ca")) {                    Plotly.newPlot(                        "24800fec-164a-4dac-9f0c-ea2712b808ca",                        [{"alignmentgroup":"True","hovertemplate":"nrgy=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[34,34,49,43,38,14,41,36,9,43,10,31,6,47,27,28,43,17,65,12,43,46,22,32,28,64,31,97,71,27,45,29,60,29,14,26,17,16,45,14,11,44,44,32,16,33,20,12,37,39,14,31,50,21,27,55,39,31,64,46,19,14,34,33,55,29,16,53,44,38,62,36,65],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"sca ...
# Box plot for dnce per genre
# <div>                            <div id="b1f07e31-c370-4093-8625-b971cb74bf89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1f07e31-c370-4093-8625-b971cb74bf89")) {                    Plotly.newPlot(                        "b1f07e31-c370-4093-8625-b971cb74bf89",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>dnce=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[55,42,26,49,56,39,29,74,37,81,51,50,37,39,57,42,51,18,55,68,45,59,49,51,37,72,59,57,59,42,21,46,55],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>dnce=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[60,47,44,32,53,35,55,45,65],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>dnce=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[67,67,36,55],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>dnce=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[38,74,36,24,71,59,70],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>dnce=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[56],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>dnce=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[48],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>dnce=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[66],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>dnce=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[53],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>dnce=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[57,57],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>dnce=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[69],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<br>dnce=%{y}<extra></extra>" ...
# Overall box plot for dnce
# <div>                            <div id="50259004-cf72-41e4-99dc-7a98e738243b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50259004-cf72-41e4-99dc-7a98e738243b")) {                    Plotly.newPlot(                        "50259004-cf72-41e4-99dc-7a98e738243b",                        [{"alignmentgroup":"True","hovertemplate":"dnce=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[55,42,26,49,56,39,29,74,37,81,51,60,50,67,67,38,37,39,47,57,42,51,18,44,55,68,45,59,49,32,56,49,41,51,37,48,72,59,74,57,36,59,53,53,42,66,35,21,55,46,29,36,55,24,53,71,45,37,88,57,69,52,57,59,65,70,57,48,55,65,62,27,70],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"s ...
# Box plot for dB per genre
# <div>                            <div id="d78e9d5c-d564-4826-be0f-9f3df179e570" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d78e9d5c-d564-4826-be0f-9f3df179e570")) {                    Plotly.newPlot(                        "d78e9d5c-d564-4826-be0f-9f3df179e570",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>dB=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-9,-11,-9,-12,-9,-18,-10,-12,-17,-12,-18,-16,-8,-15,-16,-10,-10,-17,-10,-12,-8,-7,-7,-11,-15,-13,-18,-12,-10,-16,-17,-10,-10],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>dB=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-11,-14,-10,-10,-10,-13,-9,-9,-10],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>dB=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-9,-11,-15,-15],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>dB=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-14,-10,-11,-17,-8,-10,-2],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>dB=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-7],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>dB=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-15],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>dB=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-16],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>dB=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-8],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>dB=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-9,-14],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>dB=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[-17],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<br> ...
# Overall box plot for dB
# <div>                            <div id="518da634-faa7-4b1c-b0b2-5ac35f707c0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("518da634-faa7-4b1c-b0b2-5ac35f707c0a")) {                    Plotly.newPlot(                        "518da634-faa7-4b1c-b0b2-5ac35f707c0a",                        [{"alignmentgroup":"True","hovertemplate":"dB=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[-9,-11,-9,-12,-9,-18,-10,-12,-17,-12,-18,-11,-16,-9,-11,-14,-8,-15,-14,-16,-10,-10,-17,-10,-10,-12,-8,-7,-7,-10,-7,-10,-8,-11,-15,-15,-13,-18,-10,-12,-15,-10,-8,-10,-16,-16,-13,-17,-9,-10,-10,-11,-15,-17,-8,-8,-9,-10,-9,-9,-17,-14,-14,-10,-10,-15,-16,-9,-10,-8,-7,-15,-2],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoo ...
# Box plot for live per genre
# <div>                            <div id="95b1de6c-4915-4343-b924-63b022d851b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95b1de6c-4915-4343-b924-63b022d851b9")) {                    Plotly.newPlot(                        "95b1de6c-4915-4343-b924-63b022d851b9",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>live=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[10,72,34,12,13,11,27,12,11,2,10,10,13,8,11,18,40,10,9,21,13,9,10,8,12,7,11,13,5,18,12,16,10],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>live=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[9,34,11,10,17,9,24,13,36],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>live=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[27,23,20,15],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>live=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[31,10,25,20,19,9,14],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>live=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[15],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>live=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[28],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>live=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[9],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>live=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[27],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>live=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[18,35],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>live=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[13],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<br>live=%{y}<extra></extra>","legendgro ...
# Overall box plot for live
# <div>                            <div id="7f66466d-4fe0-43d6-9612-9806dde03fa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f66466d-4fe0-43d6-9612-9806dde03fa0")) {                    Plotly.newPlot(                        "7f66466d-4fe0-43d6-9612-9806dde03fa0",                        [{"alignmentgroup":"True","hovertemplate":"live=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[10,72,34,12,13,11,27,12,11,2,10,9,10,27,23,31,13,8,34,11,18,40,10,11,9,21,13,9,10,10,15,12,41,8,12,28,7,11,10,13,20,5,13,17,18,9,9,12,24,16,15,25,15,20,27,19,13,27,60,18,13,14,35,9,36,16,11,34,10,13,25,25,14],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{" ...
# Box plot for val per genre
# <div>                            <div id="d895166e-7a33-4152-a753-be7d9e9e84ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d895166e-7a33-4152-a753-be7d9e9e84ee")) {                    Plotly.newPlot(                        "d895166e-7a33-4152-a753-be7d9e9e84ee",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>val=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[47,78,40,66,62,57,54,86,21,96,30,33,68,50,34,77,79,16,47,99,28,86,90,58,36,78,47,39,90,46,19,50,73],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>val=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[60,94,20,55,73,43,85,39,59],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>val=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[91,56,23,96],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>val=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[65,96,29,14,82,68,85],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>val=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[70],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>val=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[30],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>val=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[53],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>val=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[72],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>val=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[86,89],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>val=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[56],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic uk pop<br>val=%{y}<extra></extra>","legendgro ...
# Overall box plot for val
# ...
# Overall box plot for spch
# <div>                            <div id="1cf52cb5-5534-449a-bda2-39a586b056f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1cf52cb5-5534-449a-bda2-39a586b056f0")) {                    Plotly.newPlot(                        "1cf52cb5-5534-449a-bda2-39a586b056f0",                        [{"alignmentgroup":"True","hovertemplate":"spch=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[3,4,4,6,3,4,3,3,4,9,3,3,5,5,9,3,3,3,3,6,4,7,4,4,3,6,3,9,3,4,3,3,6,4,4,3,7,3,4,3,3,3,3,7,5,9,3,3,4,3,3,3,6,3,3,4,3,3,11,5,3,3,3,3,4,4,5,3,4,3,4,4,3],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sc ...
# Box plot for popularity per genre
# <div>                            <div id="d82bc956-432a-4a6a-a7a4-49dd4cb4fed7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d82bc956-432a-4a6a-a7a4-49dd4cb4fed7")) {                    Plotly.newPlot(                        "d82bc956-432a-4a6a-a7a4-49dd4cb4fed7",                        [{"alignmentgroup":"True","hovertemplate":"genre=adult standards<br>popularity=%{y}<extra></extra>","legendgroup":"adult standards","marker":{"color":"#636efa"},"name":"adult standards","notched":false,"offsetgroup":"adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[72,62,61,60,60,57,56,55,55,54,54,52,48,48,47,47,47,45,44,44,44,43,41,39,39,39,39,38,38,37,35,35,27],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=brill building pop<br>popularity=%{y}<extra></extra>","legendgroup":"brill building pop","marker":{"color":"#EF553B"},"name":"brill building pop","notched":false,"offsetgroup":"brill building pop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[53,48,44,41,37,36,35,32,29],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=doo-wop<br>popularity=%{y}<extra></extra>","legendgroup":"doo-wop","marker":{"color":"#00cc96"},"name":"doo-wop","notched":false,"offsetgroup":"doo-wop","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[52,51,38,33],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=deep adult standards<br>popularity=%{y}<extra></extra>","legendgroup":"deep adult standards","marker":{"color":"#ab63fa"},"name":"deep adult standards","notched":false,"offsetgroup":"deep adult standards","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[49,38,34,33,33,30,26],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british comedy<br>popularity=%{y}<extra></extra>","legendgroup":"british comedy","marker":{"color":"#FFA15A"},"name":"british comedy","notched":false,"offsetgroup":"british comedy","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[41],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=classic soul<br>popularity=%{y}<extra></extra>","legendgroup":"classic soul","marker":{"color":"#19d3f3"},"name":"classic soul","notched":false,"offsetgroup":"classic soul","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[39],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=louisiana blues<br>popularity=%{y}<extra></extra>","legendgroup":"louisiana blues","marker":{"color":"#FF6692"},"name":"louisiana blues","notched":false,"offsetgroup":"louisiana blues","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[36],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=british dance band<br>popularity=%{y}<extra></extra>","legendgroup":"british dance band","marker":{"color":"#B6E880"},"name":"british dance band","notched":false,"offsetgroup":"british dance band","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[33],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=merseybeat<br>popularity=%{y}<extra></extra>","legendgroup":"merseybeat","marker":{"color":"#FF97FF"},"name":"merseybeat","notched":false,"offsetgroup":"merseybeat","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[31,30],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"genre=yodeling<br>popularity=%{y}<extra></extra>","legendgroup":"yodeling","marker":{"color":"#FECB52"},"name":"yodeling","notched":false,"offsetgroup":"yodeling","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[31],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hover ...
# Overall box plot for popularity
# <div>                            <div id="e959e7ad-1e79-462f-ae3e-ed56d41f6e31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e959e7ad-1e79-462f-ae3e-ed56d41f6e31")) {                    Plotly.newPlot(                        "e959e7ad-1e79-462f-ae3e-ed56d41f6e31",                        [{"alignmentgroup":"True","hovertemplate":"popularity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[72,62,61,60,60,57,56,55,55,54,54,53,52,52,51,49,48,48,48,47,47,47,45,44,44,44,44,43,41,41,41,40,40,39,39,39,39,39,38,38,38,38,37,37,37,36,36,35,35,35,34,34,33,33,33,33,32,31,31,31,31,30,30,30,29,29,28,28,27,27,27,26,26],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie ...

# %%
# Correlation map
corr = song50s.corr()

print("Overall correlation map")
f, ax = plt.subplots(figsize=(18,18))
sns.heatmap(corr, annot=True, linewidths=.5, fmt=".2f", ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Pie chart of all songs by genre

groupByGenre = song50s.groupby("genre").count().sort_values(by=["title"], ascending=False)

figure = px.bar(groupByGenre["title"], y=groupByGenre.index, x="title", orientation="h")
figure.show()
# Out:
# <div>                            <div id="774a3e68-7f77-4a89-a32d-d339abc399d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("774a3e68-7f77-4a89-a32d-d339abc399d3")) {                    Plotly.newPlot(                        "774a3e68-7f77-4a89-a32d-d339abc399d3",                        [{"alignmentgroup":"True","hovertemplate":"title=%{x}<br>genre=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[33,9,7,4,2,1,1,1,1,1,1],"xaxis":"x","y":["adult standards","brill building pop","deep adult standards","doo-wop","merseybeat","british comedy","british dance band","classic soul","classic uk pop","louisiana blues","yodeling"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tr ...
